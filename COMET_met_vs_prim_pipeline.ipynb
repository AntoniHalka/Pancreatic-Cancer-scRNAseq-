# %%
## Setup (run in terminal) to load COMET and environment

# cd /blue/ferrallm/ferrallm/CMML/COMET 
# module load conda
# conda activate comet_env

# %%
## COMET run (met vs primary)
# This command was executed on HiPerGator to generate the results in clus2_output/
# marker file: res=0.05_markers_met_vs_prim.txt
# umap file: res=0.05_umap_met_vs_prim.txt
# cluster file: res=0.05_clusters_met_vs_prim.txt
# output directory: clus2_output
# gene file: res=0.05_genes_met_vs_prim.txt

Comet "res=0.05_markers_met_vs_prim.txt" \
"res=0.05_umap_met_vs_prim.txt" \
"res=0.05_clusters_met_vs_prim.txt" \
clus2_output/ \
-g "res=0.05_genes_met_vs_prim.txt" \
-C 2 -K 3 -Down 15000
